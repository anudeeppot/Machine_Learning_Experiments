# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns

print("Library Versions")
print("-" * 40)
print(f"Pandas         : {pd.__version__}")
print(f"NumPy          : {np.__version__}")
print(f"Scikit-learn   : {sklearn.__version__}")
print(f"Matplotlib     : {matplotlib.__version__}")
print(f"Seaborn        : {sns.__version__}")
# Out:
# Library Versions
# ----------------------------------------
# Pandas         : 2.2.2
# NumPy          : 2.0.2
# Scikit-learn   : 1.6.1
# Matplotlib     : 3.10.0
# Seaborn        : 0.13.2

# %%
import pandas as pd
import seaborn as sns

# %%
from pandas import read_csv
df=read_csv('student_placement_synthetic.csv')

# %%
#Displays the first ten records of the dataset.
df.head(10)
# Out:
#      branch college_tier  cgpa  backlogs  coding_skills  dsa_score  \
# 0       ECE       Tier-3  6.70         0            7.6        4.4
# 1  Chemical       Tier-2  5.70         0            5.4        7.9
# 2        EE       Tier-2  7.19         0            5.6        6.8
# 3        CE       Tier-2  6.48         0            5.2        3.1
# 4       CSE       Tier-2  6.71         1            5.9        4.7
# 5       CSE       Tier-3  6.21         1            6.7        6.5
# 6       CSE       Tier-3  7.91         0            7.0        3.9
# 7        IT       Tier-3  6.95         0            6.1        6.0
# 8        CE       Tier-2  7.03         0            5.1        2.5
# 9        EE       Tier-2  7.34         3            4.7        6.2
#
#    aptitude_score  communication_skills  ml_knowledge  system_design  \
# 0            49.5                   3.7           6.4            0.3
# 1            72.0                   8.3           6.3            1.9
# ...

# %%
#Displays the last ten records of the dataset.
df.tail(10)
# Out:
#          branch college_tier  cgpa  backlogs  coding_skills  dsa_score  \
# 99990        IT       Tier-3  8.03         0            3.4        8.6
# 99991       CSE       Tier-3  7.18         0            7.7        7.3
# 99992  Chemical       Tier-2  6.84         0            8.4        4.6
# 99993        ME       Tier-2  6.54         1            3.5        6.5
# 99994        IT       Tier-1  7.99         0            9.2        3.6
# 99995        IT       Tier-3  6.08         0            3.1        5.4
# 99996        IT       Tier-3  7.46         0            4.8        6.8
# 99997        EE       Tier-2  7.94         0            4.9        9.1
# 99998        ME       Tier-3  6.63         0            5.0        8.0
# 99999       ECE       Tier-1  7.00         0            2.8        5.3
#
#        aptitude_score  communication_skills  ml_knowledge  system_design  \
# 99990            63.7                   4.4           3.1            1.0
# ...

# %%
df.shape
# Out:
# (100000, 18)

# %%
rows, columns=df.shape
rows
# Out:
# 100000

# %%
df['cgpa']
# Out:
# 0        6.70
# 1        5.70
# 2        7.19
# 3        6.48
# 4        6.71
#          ...
# 99995    6.08
# 99996    7.46
# 99997    7.94
# 99998    6.63
# 99999    7.00
# Name: cgpa, Length: 100000, dtype: float64

# %%
df.columns
# Out:
# Index(['branch', 'college_tier', 'cgpa', 'backlogs', 'coding_skills',
#        'dsa_score', 'aptitude_score', 'communication_skills', 'ml_knowledge',
#        'system_design', 'internships', 'projects_count', 'certifications',
#        'hackathons', 'open_source_contributions', 'extracurriculars',
#        'placement_status', 'salary_package_lpa'],
#       dtype='object')

# %%
df.dtypes
# Out:
# branch                        object
# college_tier                  object
# cgpa                         float64
# backlogs                       int64
# coding_skills                float64
# dsa_score                    float64
# aptitude_score               float64
# communication_skills         float64
# ml_knowledge                 float64
# system_design                float64
# internships                    int64
# projects_count                 int64
# certifications                 int64
# hackathons                     int64
# open_source_contributions      int64
# extracurriculars               int64
# placement_status               int64
# salary_package_lpa           float64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# float64    8
# int64      8
# object     2
# Name: count, dtype: int64

# %%
import pandas as pd

# Step 1: Checking Missing Values
#Missing values are one of the most common problems in real-world datasets.
#Before training a Machine Learning model, we must identify columns containing missing values.
# df.isnull().sum()

missing_data = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": (df.isnull().sum()/len(df))*100
})

missing_data
# Out:
#                            Missing Values  Percentage
# branch                                  0       0.000
# college_tier                            0       0.000
# cgpa                                    0       0.000
# backlogs                                0       0.000
# coding_skills                           0       0.000
# dsa_score                               0       0.000
# aptitude_score                          0       0.000
# communication_skills                    0       0.000
# ml_knowledge                            0       0.000
# system_design                           0       0.000
# internships                             0       0.000
# projects_count                          0       0.000
# certifications                          0       0.000
# hackathons                              0       0.000
# open_source_contributions               0       0.000
# extracurriculars                        0       0.000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
# cbar=False hides the color bar; yticklabels=False hides row numbers for cleaner v
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap="viridis")
plt.title("missing")
plt.show()

# %%
#Keeps the first occurrence and marks subsequent duplicates as True(if any)
duplicate_rows = df[df.duplicated()]
print(f"Total duplicate rows detected: {len(duplicate_rows)}")
print(duplicate_rows)
print("-" * 40)
# Out:
# Total duplicate rows detected: 0
# Empty DataFrame
# Columns: [branch, college_tier, cgpa, backlogs, coding_skills, dsa_score, aptitude_score, communication_skills, ml_knowledge, system_design, internships, projects_count, certifications, hackathons, open_source_contributions, extracurriculars, placement_status, salary_package_lpa]
# Index: []
# ----------------------------------------

# %%
#display rows where null values are present if any
df[df['aptitude_score'].isnull()]
# Out:
# Empty DataFrame
# Columns: [branch, college_tier, cgpa, backlogs, coding_skills, dsa_score, aptitude_score, communication_skills, ml_knowledge, system_design, internships, projects_count, certifications, hackathons, open_source_contributions, extracurriculars, placement_status, salary_package_lpa]
# Index: []

# %%
#  Checking for Duplicates

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Remove Duplicates
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (100000, 18)

# %%
df.describe()
# Out:
#                 cgpa       backlogs  coding_skills      dsa_score  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        7.206381       0.547010       5.995147       5.500711
# std         0.925235       0.862727       1.496302       1.781961
# min         4.000000       0.000000       1.000000       1.000000
# 25%         6.580000       0.000000       5.000000       4.300000
# 50%         7.210000       0.000000       6.000000       5.500000
# 75%         7.830000       1.000000       7.000000       6.700000
# max        10.000000       3.000000      10.000000      10.000000
#
#        aptitude_score  communication_skills   ml_knowledge  system_design  \
# count   100000.000000         100000.000000  100000.000000  100000.000000
# mean        64.990511              5.990614       4.508752       4.008210
# std         11.990892              1.496552       1.968278       1.778405
# min         20.000000              1.000000       0.000000       0.000000
# ...

# %%
## Class Distribution

#The target variable is **Placement_Status**.
# Before building any classification model,
# we should examine the distribution of the target classes to identify whether the dataset is balanced or imbalanced.

df["placement_status"].value_counts()
# Out:
# placement_status
# 1    68475
# 0    31525
# Name: count, dtype: int64

# %%
#Percentage Distribution
(df["placement_status"].value_counts(normalize=True) * 100).round(2)
# Out:
# placement_status
# 1    68.47
# 0    31.52
# Name: proportion, dtype: float64

# %% [markdown]
# ### Relationship between CGPA and Placement Status
#
# Let's visualize the distribution of 'cgpa' for both placed and unplaced students to see if there's a clear separation or trend.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.boxplot(x='placement_status', y='cgpa', data=df, palette='viridis')
plt.title('CGPA Distribution by Placement Status')
plt.xlabel('Placement Status (0: Not Placed, 1: Placed)')
plt.ylabel('CGPA')
plt.xticks([0, 1], ['Not Placed', 'Placed'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /tmp/ipykernel_2011/781095325.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='placement_status', y='cgpa', data=df, palette='viridis')
